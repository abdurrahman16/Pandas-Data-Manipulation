# %% [markdown]
# <a href="https://colab.research.google.com/github/abdurrahman16/Pandas-Data-Manipulation/blob/main/Data_Visualizations_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
fruits=["Mango", "Banana", "Guwava", "Cherry"]
Price=[30,35,40,80]

# %%
plt.bar(fruits, Price)
# Out:
# <BarContainer object of 4 artists>

# %%
bar_labels=['red','orange','yellow','blue']
bar_colors=['tab:red','tab:orange','tab:yellow','tab:blue']

# %%
plt.bar(fruits,Price, label=bar_labels, color=['red','orange','yellow','blue'])
plt.show()

# %%
plt.scatter(fruits,Price)
plt.figure(figsize=(10,500))

# %%
plt.figure(figsize=(10,6))
plt.plot(study_hours, label='Study Hours')
plt.plot(days, label='Number of Days')
plt.plot(cgpa, label='CGPA')
plt.title("Student Performance Graph")
plt.xlabel("Study Hours")
plt.grid()
plt.ylabel("CGPA")
plt.legend()
plt.show()
plt.savefig('student_performance.png')
